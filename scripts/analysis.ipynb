# %%
import pandas as pd

df = pd.read_csv('predictions.csv')

# %%
df.head()
# Out:
#       trans_id cutoff_date      trx_channel        trx_type  trx_amt  \
# 0  83867701614  2025-07-01  Payment Gateway  Online Payment    400.0
# 1  83867776325  2025-07-01  Payment Gateway  Online Payment    400.0
# 2  83867955249  2025-07-01  Payment Gateway  Online Payment  11498.0
# 3  83866999447  2025-07-01  Payment Gateway  Online Payment   5000.0
# 4  83867641892  2025-07-01  Payment Gateway  Online Payment    300.0
#
#    fraud_flag  fraud_probability  risk_score
# 0           0           0.022782        2.28
# 1           0           0.022782        2.28
# 2           0           0.174843       17.48
# 3           0           0.136780       13.68
# 4           0           0.023126        2.31

# %%
df['risk_score'].max()
# Out:
# np.float64(96.08)

# %%
df['risk_score'].mean()
# Out:
# np.float64(7.394994689069137)

# %%
len(df[df['risk_score']>90])
# Out:
# 175

# %%
1487/1600000
# Out:
# 0.000929375
